# %% [markdown]
# # Final Project - NOPD Misconduct Complaints
#
# Source: City of New Orleans Open Data, https://catalog.data.gov/dataset/nopd-misconduct-complaints

# %%
# Reading & cleaning the data

# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_colwidth", 100)
# Out:
# /Users/sheridanwall/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.read_csv('NOPD_Misconduct_Complaints.csv')
df.head()
# Out:
#       Incident Type Complaint Tracking Number Date Complaint Occurred  \
# 0  Public Initiated               2016-0001-P              2016-01-01
# 1  Public Initiated               2016-0002-P              2016-01-02
# 2  Public Initiated               2016-0002-P              2016-01-02
# 3  Public Initiated               2016-0009-P              2016-01-04
# 4  Public Initiated               2016-0006-P              2016-12-30
#
#   Date Complaint Received by NOPD (PIB) Date Complaint Investigation Complete  \
# 0                            2016-01-01                            2016-07-21
# 1                            2016-01-01                            2016-08-03
# 2                            2016-01-01                            2016-08-03
# 3                            2016-01-04                            2017-03-20
# 4                            2016-01-04                            2016-07-25
#
#   Complaint classification Investigation status Disposition  \
# 0                     DI-1            Completed   Unfounded
# 1                     DI-1            Completed  Exonerated
# 2                     DI-1            Completed  Exonerated
# 3                     DI-1            Completed   Unfounded
# 4                     DI-1            Completed  Exonerated
#
#            Bureau of Complainant Division of Complainant Unit of Complainant  \
# 0                            NaN            8th District                 NaN
# 1  FOB - Field Operations Bureau            7th District         Night Watch
# 2  FOB - Field Operations Bureau            7th District         Night Watch
# 3  FOB - Field Operations Bureau            8th District        8th District
# 4  FOB - Field Operations Bureau           Command Staff               Admin
#
#   Unit Additional Details of Complainant Working Status of Complainant  \
# 0                                    NaN                           NaN
# 1                                 Patrol               Regular Working
# 2                                 Patrol               Regular Working
# 3                                 Patrol               Regular Working
# 4                                    NaN                           NaN
#
#   Shift of Complainant         Rule Violation  \
# 0                  NaN   RULE 3: PROF CONDUCT
# 1     Between 11pm-7am   RULE 4: PERF OF DUTY
# 2     Between 11pm-7am   RULE 4: PERF OF DUTY
# 3     Between 3pm-11pm  RULE 2: MORAL CONDUCT
# 4                  NaN   RULE 4: PERF OF DUTY
#
#                                      Paragraph Violation  \
# 0                         PARAGRAPH 01 - Professionalism
# 1                         PARAGRAPH 04 - NEGLECT OF DUTY
# 2                         PARAGRAPH 04 - NEGLECT OF DUTY
# 3                        PARAGRAPH 01 - ADHERENCE TO LAW
# 4  PARAGRAPH 02 - INSTRUCTIONS FROM AUTHORITATIVE SOURCE
#
#    Unique Officer Allegation ID Officer Race Ethnicity Officer Gender  \
# 0                       30664.0                    NaN            NaN
# 1                       30667.0                  Black           Male
# 2                       30669.0                  Black           Male
# 3                       30671.0                  White           Male
# 4                       30674.0                  Black           Male
#
#   Officer Age  Officer years of service Complainant Gender  \
# 0         NaN                       NaN               Male
# 1          60                       NaN             Female
# 2          44                       NaN             Female
# 3         NaN                       NaN                NaN
# 4          54                       NaN             Female
#
#   Complainant Ethnicity  Complainant Age
# 0                 Black              NaN
# 1                 White              NaN
# 2                 White              NaN
# 3                   NaN              NaN
# 4                 Black             50.0

# %%
df['Date Complaint Investigation Complete'] = pd.to_datetime(df["Date Complaint Investigation Complete"], format='%Y-%m-%d')

# %%
df['year_complete'] = df['Date Complaint Investigation Complete'].dt.year

# %%
df['complainant_race_clean'] = df["Complainant Ethnicity"].replace({
    'B':'Black',
    'b' : 'Black',
    'w' : 'White',
    'W':'White',
    'BLACK':'Black',
    'white':'White',
    'black':'Black',
    'Race-Unknown': np.nan,
    'Unknown': np.nan,
    'Unkown':np.nan
})
df.complainant_race_clean.value_counts()
# Out:
# Black       2092
# White        684
# Hispanic      72
# Asian         11
# Indian         1
# Name: complainant_race_clean, dtype: int64

# %%
df['officer_race_clean'] = df['Officer Race Ethnicity'].replace({
    'Black':'Black',
    'White':'White',
    'Hispanic':'Hispanic',
    'Asian/Pacifi':'Asian',
    'Not Specifie':np.nan,
    'Race-Unknown':np.nan,
    'American Ind':'Indigenous',
    'Asian/Pacif':'Asian',
    ' Giving Anything of Value':np.nan,
    'PARAGRAPH 01 - Professionalism':np.nan  
})
df.officer_race_clean.value_counts()
# Out:
# Black         2595
# White         1817
# Hispanic       238
# Asian           77
# Indigenous       9
# Name: officer_race_clean, dtype: int64

# %%
df['officer_age_clean'] = df['Officer Age'].replace({
    '-38': np.nan,
    '-8': np.nan,
    'Female': np.nan,
    'Male': np.nan
})
# df['officer_age_clean'].value_counts()

# %%
df['officer_age_clean'] = df['officer_age_clean'].astype(float)

# %%
df['officer_gender_clean'] = df['Officer Gender'].replace({
    'Male':'Male',
    'Female':'Female',
    'N': np.nan,
    'Black': np.nan,
    'White': np.nan
})
df.officer_gender_clean.value_counts()
# Out:
# Male      3779
# Female     996
# Name: officer_gender_clean, dtype: int64

# %%
df['incident_type'] = df['Incident Type']
df.incident_type.value_counts()
# Out:
# Public Initiated    3460
# Rank Initiated      1830
# Name: incident_type, dtype: int64

# %%
df['minority'] = df['officer_race_clean'].replace({
    'Black':'M',
    'White':'W',
    'Hispanic':'M',
    'Asian':'M',
    'Indigenous':'M'
})
df.minority.value_counts()
# Out:
# M    2919
# W    1817
# Name: minority, dtype: int64

# %%
#df.head()

# %% [markdown]
# # Brainstorming the regression
#
# Definition of each disposition (pg. 18): https://www.nola.gov/getattachment/NOPD/Policies/Chapter-52-1-1-Misconduct-Intake-and-Complaint-Investigation-EFFECTIVE-3-18-18.pdf/
#
# - Is the police department's discplinary board racist?
#      - Were complaints filed against Black officers marked as sustained more often than others?
#          - Controlling for gender, age? 7th district? Year?
#          - Public initiated vs. rank initiated? Does who made the complaint factor into the decision? Is the Public more likely to accuse a Black officer?
#          - Control for race of the complainant
#      - Are they dismissing complaints against white police officers more often than Black?
#      - Use unfounded vs. sustained?
#        - Unfounded—the investigation determines by a preponderance of the evidence that the alleged misconduct did not occur or did not involve the accused officer.
#        - Sustained—the investigation determines by a preponderance of the evidence that the alleged misconduct did occur.
# - Are Black officers more often reported for "serious" offenses? By who (public vs. rank)? Are complaints against Black officers more likely to result in a sustained conviction?

# %%
# df.Disposition.value_counts()

# %%
# df['Division of Complainant'].value_counts()

# %%
# df.year_complete.value_counts()

# %%
# df['incident_type'].value_counts()

# %%
# df['Officer Race Ethnicity'].value_counts()

# %%
# df['Complainant Ethnicity'].value_counts()

# %%
# df['Officer Age'].value_counts().tail(40)

# %% [markdown]
# # Preparing DataFrame for logistic regression

# %%
df2 = df[df['Disposition'] != 'Pending']
# df2.shape

# %%
df2.Disposition.value_counts()
# Out:
# Unfounded                       1121
# Sustained                        801
# Not Sustained                    582
# Other                            540
# Exonerated                       526
# NFIM                             359
# Withdrawn - Mediation            177
# Negotiated Settlement            106
# Resigned under investigation       2
# Name: Disposition, dtype: int64

# %%
df2['dispostion_new'] = df2.Disposition.replace({
    'Sustained':'S',
    'Unfounded': 'O',
    'Not Sustained':'O',
    'Other':'O',
    'Exonerated':'O',
    'NFIM':'O',
    'Withdrawn - Mediation':'O',
    'Negotiated Settlement':'O',
    'Resigned under investigation':'O'
})
# Out:
# <ipython-input-23-3cc366b8e9aa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['dispostion_new'] = df2.Disposition.replace({

# %%
# df2.head()

# %%
df2.dispostion_new.value_counts()
# Out:
# O    3413
# S     801
# Name: dispostion_new, dtype: int64

# %%
df2['sustained'] = df2.dispostion_new.replace({'S':1,'O': 0})
df2.head()
# Out:
# <ipython-input-26-2a0c18872483>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['sustained'] = df2.dispostion_new.replace({'S':1,'O': 0})
#       Incident Type Complaint Tracking Number Date Complaint Occurred  \
# 0  Public Initiated               2016-0001-P              2016-01-01
# 1  Public Initiated               2016-0002-P              2016-01-02
# 2  Public Initiated               2016-0002-P              2016-01-02
# 3  Public Initiated               2016-0009-P              2016-01-04
# 4  Public Initiated               2016-0006-P              2016-12-30
#
#   Date Complaint Received by NOPD (PIB) Date Complaint Investigation Complete  \
# 0                            2016-01-01                            2016-07-21
# 1                            2016-01-01                            2016-08-03
# 2                            2016-01-01                            2016-08-03
# 3                            2016-01-04                            2017-03-20
# 4                            2016-01-04                            2016-07-25
#
#   Complaint classification Investigation status Disposition  \
# 0                     DI-1            Completed   Unfounded
# 1                     DI-1            Completed  Exonerated
# 2                     DI-1            Completed  Exonerated
# 3                     DI-1            Completed   Unfounded
# 4                     DI-1            Completed  Exonerated
#
#            Bureau of Complainant Division of Complainant Unit of Complainant  \
# 0                            NaN            8th District                 NaN
# 1  FOB - Field Operations Bureau            7th District         Night Watch
# 2  FOB - Field Operations Bureau            7th District         Night Watch
# 3  FOB - Field Operations Bureau            8th District        8th District
# 4  FOB - Field Operations Bureau           Command Staff               Admin
#
#   Unit Additional Details of Complainant Working Status of Complainant  \
# 0                                    NaN                           NaN
# 1                                 Patrol               Regular Working
# 2                                 Patrol               Regular Working
# 3                                 Patrol               Regular Working
# 4                                    NaN                           NaN
#
#   Shift of Complainant         Rule Violation  \
# 0                  NaN   RULE 3: PROF CONDUCT
# 1     Between 11pm-7am   RULE 4: PERF OF DUTY
# 2     Between 11pm-7am   RULE 4: PERF OF DUTY
# 3     Between 3pm-11pm  RULE 2: MORAL CONDUCT
# 4                  NaN   RULE 4: PERF OF DUTY
#
#                                      Paragraph Violation  \
# 0                         PARAGRAPH 01 - Professionalism
# 1                         PARAGRAPH 04 - NEGLECT OF DUTY
# 2                         PARAGRAPH 04 - NEGLECT OF DUTY
# 3                        PARAGRAPH 01 - ADHERENCE TO LAW
# 4  PARAGRAPH 02 - INSTRUCTIONS FROM AUTHORITATIVE SOURCE
#
#    Unique Officer Allegation ID Officer Race Ethnicity Officer Gender  \
# 0                       30664.0                    NaN            NaN
# 1                       30667.0                  Black           Male
# 2                       30669.0                  Black           Male
# 3                       30671.0                  White           Male
# 4                       30674.0                  Black           Male
#
#   Officer Age  Officer years of service Complainant Gender  \
# 0         NaN                       NaN               Male
# 1          60                       NaN             Female
# 2          44                       NaN             Female
# 3         NaN                       NaN                NaN
# 4          54                       NaN             Female
#
#   Complainant Ethnicity  Complainant Age  year_complete  \
# 0                 Black              NaN         2016.0
# 1                 White              NaN         2016.0
# 2                 White              NaN         2016.0
# 3                   NaN              NaN         2017.0
# 4                 Black             50.0         2016.0
#
#   complainant_race_clean officer_race_clean  officer_age_clean  \
# 0                  Black                NaN                NaN
# 1                  White              Black               60.0
# 2                  White              Black               44.0
# 3                    NaN              White                NaN
# 4                  Black              Black               54.0
#
#   officer_gender_clean     incident_type minority dispostion_new  sustained
# 0                  NaN  Public Initiated      NaN              O          0
# 1                 Male  Public Initiated        M              O          0
# 2                 Male  Public Initiated        M              O          0
# 3                 Male  Public Initiated        W              O          0
# 4                 Male  Public Initiated        M              O          0

# %%
labels = [
    'under 25',
    '25-38',
    '39-54',
    '55-69',
    'over 70'
]
breaks = [0, 25, 39, 55, 70, 999]
df2['officer_age_bin'] = pd.cut(df2['officer_age_clean'], bins=breaks, labels=labels)
df2.head()
# Out:
# <ipython-input-27-05dffa1b8b85>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['officer_age_bin'] = pd.cut(df2['officer_age_clean'], bins=breaks, labels=labels)
#       Incident Type Complaint Tracking Number Date Complaint Occurred  \
# 0  Public Initiated               2016-0001-P              2016-01-01
# 1  Public Initiated               2016-0002-P              2016-01-02
# 2  Public Initiated               2016-0002-P              2016-01-02
# 3  Public Initiated               2016-0009-P              2016-01-04
# 4  Public Initiated               2016-0006-P              2016-12-30
#
#   Date Complaint Received by NOPD (PIB) Date Complaint Investigation Complete  \
# 0                            2016-01-01                            2016-07-21
# 1                            2016-01-01                            2016-08-03
# 2                            2016-01-01                            2016-08-03
# 3                            2016-01-04                            2017-03-20
# 4                            2016-01-04                            2016-07-25
#
#   Complaint classification Investigation status Disposition  \
# 0                     DI-1            Completed   Unfounded
# 1                     DI-1            Completed  Exonerated
# 2                     DI-1            Completed  Exonerated
# 3                     DI-1            Completed   Unfounded
# 4                     DI-1            Completed  Exonerated
#
#            Bureau of Complainant Division of Complainant Unit of Complainant  \
# 0                            NaN            8th District                 NaN
# 1  FOB - Field Operations Bureau            7th District         Night Watch
# 2  FOB - Field Operations Bureau            7th District         Night Watch
# 3  FOB - Field Operations Bureau            8th District        8th District
# 4  FOB - Field Operations Bureau           Command Staff               Admin
#
#   Unit Additional Details of Complainant Working Status of Complainant  \
# 0                                    NaN                           NaN
# 1                                 Patrol               Regular Working
# 2                                 Patrol               Regular Working
# 3                                 Patrol               Regular Working
# 4                                    NaN                           NaN
#
#   Shift of Complainant         Rule Violation  \
# 0                  NaN   RULE 3: PROF CONDUCT
# 1     Between 11pm-7am   RULE 4: PERF OF DUTY
# 2     Between 11pm-7am   RULE 4: PERF OF DUTY
# 3     Between 3pm-11pm  RULE 2: MORAL CONDUCT
# 4                  NaN   RULE 4: PERF OF DUTY
#
#                                      Paragraph Violation  \
# 0                         PARAGRAPH 01 - Professionalism
# 1                         PARAGRAPH 04 - NEGLECT OF DUTY
# 2                         PARAGRAPH 04 - NEGLECT OF DUTY
# 3                        PARAGRAPH 01 - ADHERENCE TO LAW
# 4  PARAGRAPH 02 - INSTRUCTIONS FROM AUTHORITATIVE SOURCE
#
#    Unique Officer Allegation ID Officer Race Ethnicity Officer Gender  \
# 0                       30664.0                    NaN            NaN
# 1                       30667.0                  Black           Male
# 2                       30669.0                  Black           Male
# 3                       30671.0                  White           Male
# 4                       30674.0                  Black           Male
#
#   Officer Age  Officer years of service Complainant Gender  \
# 0         NaN                       NaN               Male
# 1          60                       NaN             Female
# 2          44                       NaN             Female
# 3         NaN                       NaN                NaN
# 4          54                       NaN             Female
#
#   Complainant Ethnicity  Complainant Age  year_complete  \
# 0                 Black              NaN         2016.0
# 1                 White              NaN         2016.0
# 2                 White              NaN         2016.0
# 3                   NaN              NaN         2017.0
# 4                 Black             50.0         2016.0
#
#   complainant_race_clean officer_race_clean  officer_age_clean  \
# 0                  Black                NaN                NaN
# 1                  White              Black               60.0
# 2                  White              Black               44.0
# 3                    NaN              White                NaN
# 4                  Black              Black               54.0
#
#   officer_gender_clean     incident_type minority dispostion_new  sustained  \
# 0                  NaN  Public Initiated      NaN              O          0
# 1                 Male  Public Initiated        M              O          0
# 2                 Male  Public Initiated        M              O          0
# 3                 Male  Public Initiated        W              O          0
# 4                 Male  Public Initiated        M              O          0
#
#   officer_age_bin
# 0             NaN
# 1           55-69
# 2           39-54
# 3             NaN
# 4           39-54

# %%
df2.officer_age_bin.value_counts()
# Out:
# 25-38       1659
# 39-54       1450
# 55-69        227
# under 25     179
# over 70        8
# Name: officer_age_bin, dtype: int64

# %%
new_df = df2.drop(columns = ['Incident Type', 'Date Complaint Received by NOPD (PIB)', 'Complaint classification',
                  'Bureau of Complainant','Division of Complainant','Unit of Complainant','Date Complaint Occurred',
                  'Unit Additional Details of Complainant','Working Status of Complainant','Shift of Complainant',
                 'Unique Officer Allegation ID','Officer Race Ethnicity','Officer Age','Officer years of service',
                 'Officer Gender','Complainant Gender','Complainant Ethnicity','Complainant Age'])

# %%
new_df = new_df.dropna()
new_df.shape
# Out:
# (2050, 16)

# %%
new_df.head()
# Out:
#   Complaint Tracking Number Date Complaint Investigation Complete  \
# 1               2016-0002-P                            2016-08-03
# 2               2016-0002-P                            2016-08-03
# 4               2016-0006-P                            2016-07-25
# 5               2016-0007-P                            2016-07-25
# 8               2016-0003-P                            2016-06-09
#
#   Investigation status Disposition        Rule Violation  \
# 1            Completed  Exonerated  RULE 4: PERF OF DUTY
# 2            Completed  Exonerated  RULE 4: PERF OF DUTY
# 4            Completed  Exonerated  RULE 4: PERF OF DUTY
# 5            Completed   Unfounded  RULE 4: PERF OF DUTY
# 8            Completed   Unfounded  RULE 4: PERF OF DUTY
#
#                                      Paragraph Violation  year_complete  \
# 1                         PARAGRAPH 04 - NEGLECT OF DUTY         2016.0
# 2                         PARAGRAPH 04 - NEGLECT OF DUTY         2016.0
# 4  PARAGRAPH 02 - INSTRUCTIONS FROM AUTHORITATIVE SOURCE         2016.0
# 5  PARAGRAPH 02 - INSTRUCTIONS FROM AUTHORITATIVE SOURCE         2016.0
# 8                         PARAGRAPH 04 - NEGLECT OF DUTY         2016.0
#
#   complainant_race_clean officer_race_clean  officer_age_clean  \
# 1                  White              Black               60.0
# 2                  White              Black               44.0
# 4                  Black              Black               54.0
# 5                  Black              Black               53.0
# 8                  White              Black               41.0
#
#   officer_gender_clean     incident_type minority dispostion_new  sustained  \
# 1                 Male  Public Initiated        M              O          0
# 2                 Male  Public Initiated        M              O          0
# 4                 Male  Public Initiated        M              O          0
# 5                 Male  Public Initiated        M              O          0
# 8                 Male  Public Initiated        M              O          0
#
#   officer_age_bin
# 1           55-69
# 2           39-54
# 4           39-54
# 5           39-54
# 8           39-54

# %% [markdown]
# # Testing logistic regressions

# %%
model = smf.logit("""
    sustained ~ 
        C(officer_race_clean, Treatment('White'))       
""", data=df2)
results = model.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.510232
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              sustained   No. Observations:                 3817
# Model:                          Logit   Df Residuals:                     3812
# Method:                           MLE   Df Model:                            4
# Date:                Wed, 07 Apr 2021   Pseudo R-squ.:               6.371e-05
# Time:                        12:15:38   Log-Likelihood:                -1947.6
# converged:                       True   LL-Null:                       -1947.7
# Covariance Type:            nonrobust   LLR p-value:                    0.9929
# ===========================================================================================================================
#                                                               coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  -1.3558      0.065    -20.940      0.000      -1.483      -1.229
# C(officer_race_clean, Treatment('White'))[T.Asian]         -0.0094      0.330     -0.029      0.977      -0.656       0.637
# C(officer_race_clean, Treatment('White'))[T.Black]          0.0294      0.084      0.349      0.727      -0.135       0.194
# C(officer_race_clean, Treatment('White'))[T.Hispanic]      -0.0435      0.192     -0.226      0.821      -0.421       0.333
# C(officer_race_clean, Treatment('White'))[T.Indigenous]     0.1031      0.804      0.128      0.898      -1.474       1.680
# ===========================================================================================================================
# """

# %%
coefs = pd.DataFrame({
    'coef': results.params.values,
    'odds ratio': np.exp(results.params.values),
    'pvalue': results.pvalues,
    'name': results.params.index
})
coefs
# Out:
#                                                              coef  odds ratio  \
# Intercept                                               -1.355835    0.257732
# C(officer_race_clean, Treatment('White'))[T.Asian]      -0.009406    0.990638
# C(officer_race_clean, Treatment('White'))[T.Black]       0.029383    1.029819
# C(officer_race_clean, Treatment('White'))[T.Hispanic]   -0.043531    0.957403
# C(officer_race_clean, Treatment('White'))[T.Indigenous]  0.103072    1.108571
#
#                                                                pvalue  \
# Intercept                                                2.322119e-97
# C(officer_race_clean, Treatment('White'))[T.Asian]       9.772512e-01
# C(officer_race_clean, Treatment('White'))[T.Black]       7.268450e-01
# C(officer_race_clean, Treatment('White'))[T.Hispanic]    8.209657e-01
# C(officer_race_clean, Treatment('White'))[T.Indigenous]  8.980410e-01
#
#                                                                                                             name
# Intercept                                                                                              Intercept
# C(officer_race_clean, Treatment('White'))[T.Asian]            C(officer_race_clean, Treatment('White'))[T.Asian]
# C(officer_race_clean, Treatment('White'))[T.Black]            C(officer_race_clean, Treatment('White'))[T.Black]
# C(officer_race_clean, Treatment('White'))[T.Hispanic]      C(officer_race_clean, Treatment('White'))[T.Hispanic]
# C(officer_race_clean, Treatment('White'))[T.Indigenous]  C(officer_race_clean, Treatment('White'))[T.Indigenous]

# %%
df2.head()
# Out:
#       Incident Type Complaint Tracking Number Date Complaint Occurred  \
# 0  Public Initiated               2016-0001-P              2016-01-01
# 1  Public Initiated               2016-0002-P              2016-01-02
# 2  Public Initiated               2016-0002-P              2016-01-02
# 3  Public Initiated               2016-0009-P              2016-01-04
# 4  Public Initiated               2016-0006-P              2016-12-30
#
#   Date Complaint Received by NOPD (PIB) Date Complaint Investigation Complete  \
# 0                            2016-01-01                            2016-07-21
# 1                            2016-01-01                            2016-08-03
# 2                            2016-01-01                            2016-08-03
# 3                            2016-01-04                            2017-03-20
# 4                            2016-01-04                            2016-07-25
#
#   Complaint classification Investigation status Disposition  \
# 0                     DI-1            Completed   Unfounded
# 1                     DI-1            Completed  Exonerated
# 2                     DI-1            Completed  Exonerated
# 3                     DI-1            Completed   Unfounded
# 4                     DI-1            Completed  Exonerated
#
#            Bureau of Complainant Division of Complainant Unit of Complainant  \
# 0                            NaN            8th District                 NaN
# 1  FOB - Field Operations Bureau            7th District         Night Watch
# 2  FOB - Field Operations Bureau            7th District         Night Watch
# 3  FOB - Field Operations Bureau            8th District        8th District
# 4  FOB - Field Operations Bureau           Command Staff               Admin
#
#   Unit Additional Details of Complainant Working Status of Complainant  \
# 0                                    NaN                           NaN
# 1                                 Patrol               Regular Working
# 2                                 Patrol               Regular Working
# 3                                 Patrol               Regular Working
# 4                                    NaN                           NaN
#
#   Shift of Complainant         Rule Violation  \
# 0                  NaN   RULE 3: PROF CONDUCT
# 1     Between 11pm-7am   RULE 4: PERF OF DUTY
# 2     Between 11pm-7am   RULE 4: PERF OF DUTY
# 3     Between 3pm-11pm  RULE 2: MORAL CONDUCT
# 4                  NaN   RULE 4: PERF OF DUTY
#
#                                      Paragraph Violation  \
# 0                         PARAGRAPH 01 - Professionalism
# 1                         PARAGRAPH 04 - NEGLECT OF DUTY
# 2                         PARAGRAPH 04 - NEGLECT OF DUTY
# 3                        PARAGRAPH 01 - ADHERENCE TO LAW
# 4  PARAGRAPH 02 - INSTRUCTIONS FROM AUTHORITATIVE SOURCE
#
#    Unique Officer Allegation ID Officer Race Ethnicity Officer Gender  \
# 0                       30664.0                    NaN            NaN
# 1                       30667.0                  Black           Male
# 2                       30669.0                  Black           Male
# 3                       30671.0                  White           Male
# 4                       30674.0                  Black           Male
#
#   Officer Age  Officer years of service Complainant Gender  \
# 0         NaN                       NaN               Male
# 1          60                       NaN             Female
# 2          44                       NaN             Female
# 3         NaN                       NaN                NaN
# 4          54                       NaN             Female
#
#   Complainant Ethnicity  Complainant Age  year_complete  \
# 0                 Black              NaN         2016.0
# 1                 White              NaN         2016.0
# 2                 White              NaN         2016.0
# 3                   NaN              NaN         2017.0
# 4                 Black             50.0         2016.0
#
#   complainant_race_clean officer_race_clean  officer_age_clean  \
# 0                  Black                NaN                NaN
# 1                  White              Black               60.0
# 2                  White              Black               44.0
# 3                    NaN              White                NaN
# 4                  Black              Black               54.0
#
#   officer_gender_clean     incident_type minority dispostion_new  sustained  \
# 0                  NaN  Public Initiated      NaN              O          0
# 1                 Male  Public Initiated        M              O          0
# 2                 Male  Public Initiated        M              O          0
# 3                 Male  Public Initiated        W              O          0
# 4                 Male  Public Initiated        M              O          0
#
#   officer_age_bin
# 0             NaN
# 1           55-69
# 2           39-54
# 3             NaN
# 4           39-54

# %%
model = smf.logit("""
    sustained ~ 
        C(minority, Treatment('W'))
        + C(officer_gender_clean, Treatment('Female'))
        + C(incident_type, Treatment('Public Initiated'))
""", data=df2)
results = model.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.473037
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              sustained   No. Observations:                 3817
# Model:                          Logit   Df Residuals:                     3813
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 07 Apr 2021   Pseudo R-squ.:                 0.07296
# Time:                        12:15:38   Log-Likelihood:                -1805.6
# converged:                       True   LL-Null:                       -1947.7
# Covariance Type:            nonrobust   LLR p-value:                 2.619e-61
# =====================================================================================================================================
#                                                                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                            -2.1208      0.123    -17.193      0.000      -2.363      -1.879
# C(minority, Treatment('W'))[T.M]                                      0.0177      0.087      0.203      0.839      -0.153       0.188
# C(officer_gender_clean, Treatment('Female'))[T.Male]                  0.2653      0.106      2.512      0.012       0.058       0.472
# C(incident_type, Treatment('Public Initiated'))[T.Rank Initiated]     1.3862      0.083     16.612      0.000       1.223       1.550
# =====================================================================================================================================
# """

# %%
coefs = pd.DataFrame({
    'coef': results.params.values,
    'odds ratio': np.exp(results.params.values),
    'pvalue': results.pvalues,
    'name': results.params.index
})
coefs
# Out:
#                                                                        coef  \
# Intercept                                                         -2.120770
# C(minority, Treatment('W'))[T.M]                                   0.017657
# C(officer_gender_clean, Treatment('Female'))[T.Male]               0.265258
# C(incident_type, Treatment('Public Initiated'))[T.Rank Initiated]  1.386168
#
#                                                                    odds ratio  \
# Intercept                                                            0.119939
# C(minority, Treatment('W'))[T.M]                                     1.017814
# C(officer_gender_clean, Treatment('Female'))[T.Male]                 1.303767
# C(incident_type, Treatment('Public Initiated'))[T.Rank Initiated]    3.999495
#
#                                                                          pvalue  \
# Intercept                                                          3.000270e-66
# C(minority, Treatment('W'))[T.M]                                   8.389938e-01
# C(officer_gender_clean, Treatment('Female'))[T.Male]               1.202003e-02
# C(incident_type, Treatment('Public Initiated'))[T.Rank Initiated]  5.730806e-62
#
#                                                                                                                                 name
# Intercept                                                                                                                  Intercept
# C(minority, Treatment('W'))[T.M]                                                                    C(minority, Treatment('W'))[T.M]
# C(officer_gender_clean, Treatment('Female'))[T.Male]                            C(officer_gender_clean, Treatment('Female'))[T.Male]
# C(incident_type, Treatment('Public Initiated'))[T.Rank Initiated]  C(incident_type, Treatment('Public Initiated'))[T.Rank Initiated]

# %%
model = smf.logit("""
    sustained ~ 
        C(minority, Treatment('W'))
        + C(officer_gender_clean, Treatment('Male'))
        + C(incident_type, Treatment('Public Initiated'))
        + C(officer_age_bin, Treatment('25-38'))
""", data=df2)
results = model.fit()
results.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.472642
#          Iterations: 35
# /Users/sheridanwall/.pyenv/versions/3.8.2/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              sustained   No. Observations:                 3498
# Model:                          Logit   Df Residuals:                     3490
# Method:                           MLE   Df Model:                            7
# Date:                Wed, 07 Apr 2021   Pseudo R-squ.:                 0.07999
# Time:                        12:23:54   Log-Likelihood:                -1653.3
# converged:                      False   LL-Null:                       -1797.1
# Covariance Type:            nonrobust   LLR p-value:                 2.824e-58
# =====================================================================================================================================
#                                                                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                            -1.8492      0.092    -20.118      0.000      -2.029      -1.669
# C(minority, Treatment('W'))[T.M]                                      0.0128      0.092      0.139      0.890      -0.168       0.194
# C(officer_gender_clean, Treatment('Male'))[T.Female]                 -0.2332      0.112     -2.085      0.037      -0.452      -0.014
# C(incident_type, Treatment('Public Initiated'))[T.Rank Initiated]     1.4482      0.087     16.622      0.000       1.277       1.619
# C(officer_age_bin, Treatment('25-38'))[T.under 25]                    0.0146      0.201      0.073      0.942      -0.379       0.408
# C(officer_age_bin, Treatment('25-38'))[T.39-54]                      -0.0650      0.094     -0.693      0.488      -0.249       0.119
# C(officer_age_bin, Treatment('25-38'))[T.55-69]                       0.0484      0.180      0.269      0.788      -0.304       0.400
# C(officer_age_bin, Treatment('25-38'))[T.over 70]                   -17.6936   8762.720     -0.002      0.998   -1.72e+04    1.72e+04
# =====================================================================================================================================
# """

# %%
coefs = pd.DataFrame({
    'coef': results.params.values,
    'odds ratio': np.exp(results.params.values),
    'pvalue': results.pvalues,
    'name': results.params.index
})
coefs
# Out:
#                                                                         coef  \
# Intercept                                                          -1.849183
# C(minority, Treatment('W'))[T.M]                                    0.012795
# C(officer_gender_clean, Treatment('Male'))[T.Female]               -0.233205
# C(incident_type, Treatment('Public Initiated'))[T.Rank Initiated]   1.448157
# C(officer_age_bin, Treatment('25-38'))[T.under 25]                  0.014646
# C(officer_age_bin, Treatment('25-38'))[T.39-54]                    -0.064998
# C(officer_age_bin, Treatment('25-38'))[T.55-69]                     0.048351
# C(officer_age_bin, Treatment('25-38'))[T.over 70]                 -17.693635
#
#                                                                      odds ratio  \
# Intercept                                                          1.573657e-01
# C(minority, Treatment('W'))[T.M]                                   1.012877e+00
# C(officer_gender_clean, Treatment('Male'))[T.Female]               7.919913e-01
# C(incident_type, Treatment('Public Initiated'))[T.Rank Initiated]  4.255267e+00
# C(officer_age_bin, Treatment('25-38'))[T.under 25]                 1.014754e+00
# C(officer_age_bin, Treatment('25-38'))[T.39-54]                    9.370691e-01
# C(officer_age_bin, Treatment('25-38'))[T.55-69]                    1.049539e+00
# C(officer_age_bin, Treatment('25-38'))[T.over 70]                  2.068959e-08
#
#                                                                          pvalue  \
# Intercept                                                          5.177686e-90
# C(minority, Treatment('W'))[T.M]                                   8.897253e-01
# C(officer_gender_clean, Treatment('Male'))[T.Female]               3.703136e-02
# C(incident_type, Treatment('Public Initiated'))[T.Rank Initiated]  4.856171e-62
# C(officer_age_bin, Treatment('25-38'))[T.under 25]                 9.418631e-01
# C(officer_age_bin, Treatment('25-38'))[T.39-54]                    4.884349e-01
# C(officer_age_bin, Treatment('25-38'))[T.55-69]                    7.877151e-01
# C(officer_age_bin, Treatment('25-38'))[T.over 70]                  9.983889e-01
#
#                                                                                                                                 name
# Intercept                                                                                                                  Intercept
# C(minority, Treatment('W'))[T.M]                                                                    C(minority, Treatment('W'))[T.M]
# C(officer_gender_clean, Treatment('Male'))[T.Female]                            C(officer_gender_clean, Treatment('Male'))[T.Female]
# C(incident_type, Treatment('Public Initiated'))[T.Rank Initiated]  C(incident_type, Treatment('Public Initiated'))[T.Rank Initiated]
# C(officer_age_bin, Treatment('25-38'))[T.under 25]                                C(officer_age_bin, Treatment('25-38'))[T.under 25]
# C(officer_age_bin, Treatment('25-38'))[T.39-54]                                      C(officer_age_bin, Treatment('25-38'))[T.39-54]
# C(officer_age_bin, Treatment('25-38'))[T.55-69]                                      C(officer_age_bin, Treatment('25-38'))[T.55-69]
# C(officer_age_bin, Treatment('25-38'))[T.over 70]                                  C(officer_age_bin, Treatment('25-38'))[T.over 70]

# %% [markdown]
# # Testing the regression with new dataframe

# %%
model = smf.logit("""
    sustained ~ 
        C(minority, Treatment('W'))
        + C(officer_gender_clean, Treatment('Male'))
        + C(incident_type, Treatment('Public Initiated'))
        + C(officer_age_bin, Treatment('25-38'))
""", data=new_df)
results = model.fit()
results.summary()

# %%
coefs = pd.DataFrame({
    'coef': results.params.values,
    'odds ratio': np.exp(results.params.values),
    'pvalue': results.pvalues,
    'name': results.params.index
})
coefs
